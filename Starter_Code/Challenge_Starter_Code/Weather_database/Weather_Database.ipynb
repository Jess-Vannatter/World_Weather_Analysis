# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 756

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_description})
                          #"Date": city_date})
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | kiunga
# Processing Record 4 of Set 1 | pauini
# Processing Record 5 of Set 1 | plettenberg bay
# Processing Record 6 of Set 1 | iqaluit
# Processing Record 7 of Set 1 | naze
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | kavaratti
# Processing Record 11 of Set 1 | dali
# Processing Record 12 of Set 1 | saint george
# Processing Record 13 of Set 1 | chuy
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | ust-maya
# Processing Record 16 of Set 1 | bengkulu
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | khanpur
# Processing Record 22 of Set 1 | yokadouma
# Processing Record 23 of Set 1 | coahuayana
# Processing Record 24 of Set 1 | geraldton
# Processing Record 25 of Set 1 | pevek
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | pekan
# Processing Record 29 of Set 1 | tilichiki
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | yuanping
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | krasnoselkup
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | chokurdakh
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | lebu
# Processing Record 43 of Set 1 | mount gambier
# Processing Record 44 of Set 1 | dryden
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | amapa
# Processing Record 47 of Set 1 | bubaque
# Processing Record 48 of Set 1 | cidreira
# Processing Record 49 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | upernavik
# Processing Record 2 of Set 2 | vermilion
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | hulan ergi
# Processing Record 6 of Set 2 | whitehorse
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | henties bay
# Processing Record 9 of Set 2 | turukhansk
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | saint-philippe
# Processing Record 12 of Set 2 | avera
# Processing Record 13 of Set 2 | lorengau
# Processing Record 14 of Set 2 | andenes
# Processing Record 15 of Set 2 | butaritari
# Processing Record 16 of Set 2 | kruisfontein
# Processing Record 17 of Set 2 | zhuanghe
# Processing Record 18 of Set 2 | saskylakh
# Processing Record 19 of Set 2 | rabak
# Processing Record 20 of Set 2 | hastings
# Processing Record 21 of Set 2 | souillac
# Processing Record 22 of Set 2 | lagoa
# Processing Record 23 of Set 2 | vanavara
# Processing Record 24 of Set 2 | lakeside
# Processing Record 25 of Set 2 | jamestown
# Processing Record 26 of Set 2 | asau
# Processing Record 27 of Set 2 | russell
# Processing Record 28 of Set 2 | caxito
# Processing Record 29 of Set 2 | savalou
# Processing Record 30 of Set 2 | khilok
# Processing Record 31 of Set 2 | puerto ayora
# Processing Record 32 of Set 2 | miri
# Processing Record 33 of Set 2 | ukiah
# Processing Record 34 of Set 2 | tiksi
# Processing Record 35 of Set 2 | kavieng
# Processing Record 36 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 2 | kismayo
# Processing Record 38 of Set 2 | saint marys
# Processing Record 39 of Set 2 | aykhal
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | cherskiy
# Processing Record 42 of Set 2 | dingle
# Processing Record 43 of Set 2 | eenhana
# Processing Record 44 of Set 2 | ilulissat
# Processing Record 45 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 2 | mogadishu
# Processing Record 47 of Set 2 | pangnirtung
# Processing Record 48 of Set 2 | belyy yar
# Processing Record 49 of Set 2 | bilibino
# Processing Record 50 of Set 2 | iquique
# Processing Record 1 of Set 3 | holme
# Processing Record 2 of Set 3 | amga
# Processing Record 3 of Set 3 | mecca
# Processing Record 4 of Set 3 | adrar
# Processing Record 5 of Set 3 | los llanos de aridane
# Processing Record 6 of Set 3 | sri aman
# Processing Record 7 of Set 3 | redmond
# Processing Record 8 of Set 3 | santa maria
# Processing Record 9 of Set 3 | northam
# Processing Record 10 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 3 | port-gentil
# Processing Record 13 of Set 3 | harper
# Processing Record 14 of Set 3 | avarua
# Processing Record 15 of Set 3 | yaan
# Processing Record 16 of Set 3 | praya
# Processing Record 17 of Set 3 | vestmannaeyjar
# Processing Record 18 of Set 3 | shingu
# Processing Record 19 of Set 3 | narsaq
# Processing Record 20 of Set 3 | devonport
# Processing Record 21 of Set 3 | klaksvik
# Processing Record 22 of Set 3 | svetlogorsk
# Processing Record 23 of Set 3 | faya
# Processing Record 24 of Set 3 | kodiak
# Processing Record 25 of Set 3 | chambishi
# Processing Record 26 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 3 | erdenet
# Processing Record 28 of Set 3 | altamira
# Processing Record 29 of Set 3 | san cristobal
# Processing Record 30 of Set 3 | bridlington
# Processing Record 31 of Set 3 | asfi
# Processing Record 32 of Set 3 | buraydah
# Processing Record 33 of Set 3 | nabire
# Processing Record 34 of Set 3 | qaqortoq
# Processing Record 35 of Set 3 | nanortalik
# Processing Record 36 of Set 3 | dikson
# Processing Record 37 of Set 3 | aksu
# Processing Record 38 of Set 3 | yurty
# Processing Record 39 of Set 3 | sola
# Processing Record 40 of Set 3 | pedernales
# Processing Record 41 of Set 3 | warmbad
# Processing Record 42 of Set 3 | ribeira grande
# Processing Record 43 of Set 3 | neryungri
# Processing Record 44 of Set 3 | broome
# Processing Record 45 of Set 3 | maniitsoq
# Processing Record 46 of Set 3 | codrington
# Processing Record 47 of Set 3 | waddan
# Processing Record 48 of Set 3 | abu dhabi
# Processing Record 49 of Set 3 | pasco
# Processing Record 50 of Set 3 | bilma
# Processing Record 1 of Set 4 | rawah
# Processing Record 2 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 4 | westport
# Processing Record 4 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 4 | wonopringgo
# Processing Record 7 of Set 4 | sambava
# Processing Record 8 of Set 4 | solsvik
# City not found. Skipping...
# Processing Record 9 of Set 4 | jiuquan
# Processing Record 10 of Set 4 | marystown
# Processing Record 11 of Set 4 | bredasdorp
# Processing Record 12 of Set 4 | tuatapere
# Processing Record 13 of Set 4 | balykshi
# Processing Record 14 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 4 | luderitz
# Processing Record 16 of Set 4 | east london
# Processing Record 17 of Set 4 | haines junction
# Processing Record 18 of Set 4 | hailar
# Processing Record 19 of Set 4 | neuquen
# Processing Record 20 of Set 4 | lasa
# Processing Record 21 of Set 4 | yumen
# Processing Record 22 of Set 4 | zhenlai
# Processing Record 23 of Set 4 | khatanga
# Processing Record 24 of Set 4 | aklavik
# Processing Record 25 of Set 4 | poum
# Processing Record 26 of Set 4 | washington
# Processing Record 27 of Set 4 | hollins
# Processing Record 28 of Set 4 | mahebourg
# Processing Record 29 of Set 4 | paralimni
# Processing Record 30 of Set 4 | labuhan
# Processing Record 31 of Set 4 | teknaf
# Processing Record 32 of Set 4 | kupino
# Processing Record 33 of Set 4 | makakilo city
# Processing Record 34 of Set 4 | yatou
# Processing Record 35 of Set 4 | bluff
# Processing Record 36 of Set 4 | torre del greco
# Processing Record 37 of Set 4 | vuktyl
# Processing Record 38 of Set 4 | lompoc
# Processing Record 39 of Set 4 | umm lajj
# Processing Record 40 of Set 4 | wageningen
# Processing Record 41 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 42 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 4 | thompson
# Processing Record 44 of Set 4 | olinda
# Processing Record 45 of Set 4 | broken hill
# Processing Record 46 of Set 4 | torbay
# Processing Record 47 of Set 4 | victoria
# Processing Record 48 of Set 4 | arraial do cabo
# Processing Record 49 of Set 4 | mar del plata
# Processing Record 50 of Set 4 | leningradskiy
# Processing Record 1 of Set 5 | amahai
# Processing Record 2 of Set 5 | cape town
# Processing Record 3 of Set 5 | dunedin
# Processing Record 4 of Set 5 | savonlinna
# Processing Record 5 of Set 5 | clyde river
# Processing Record 6 of Set 5 | sawakin
# Processing Record 7 of Set 5 | shimoda
# Processing Record 8 of Set 5 | pacific grove
# Processing Record 9 of Set 5 | wick
# Processing Record 10 of Set 5 | buin
# Processing Record 11 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 5 | outram
# Processing Record 13 of Set 5 | norman wells
# Processing Record 14 of Set 5 | severo-kurilsk
# Processing Record 15 of Set 5 | la ronge
# Processing Record 16 of Set 5 | escanaba
# Processing Record 17 of Set 5 | tuktoyaktuk
# Processing Record 18 of Set 5 | burica
# City not found. Skipping...
# Processing Record 19 of Set 5 | bathsheba
# Processing Record 20 of Set 5 | divisoria
# Processing Record 21 of Set 5 | eyl
# Processing Record 22 of Set 5 | surt
# Processing Record 23 of Set 5 | porto murtinho
# Processing Record 24 of Set 5 | sao filipe
# Processing Record 25 of Set 5 | katsuura
# Processing Record 26 of Set 5 | muros
# Processing Record 27 of Set 5 | kologriv
# Processing Record 28 of Set 5 | enumclaw
# Processing Record 29 of Set 5 | casambalangan
# Processing Record 30 of Set 5 | korla
# Processing Record 31 of Set 5 | manokwari
# Processing Record 32 of Set 5 | egvekinot
# Processing Record 33 of Set 5 | tortoli
# Processing Record 34 of Set 5 | aksum
# Processing Record 35 of Set 5 | akyab
# Processing Record 36 of Set 5 | ternate
# Processing Record 37 of Set 5 | faanui
# Processing Record 38 of Set 5 | saint-francois
# Processing Record 39 of Set 5 | mookane
# Processing Record 40 of Set 5 | namibe
# Processing Record 41 of Set 5 | asilah
# Processing Record 42 of Set 5 | kindu
# Processing Record 43 of Set 5 | alepe
# Processing Record 44 of Set 5 | corn island
# Processing Record 45 of Set 5 | kinkala
# Processing Record 46 of Set 5 | nome
# Processing Record 47 of Set 5 | berlevag
# Processing Record 48 of Set 5 | avanigadda
# Processing Record 49 of Set 5 | saldanha
# Processing Record 50 of Set 5 | strezhevoy
# Processing Record 1 of Set 6 | mahibadhoo
# Processing Record 2 of Set 6 | muisne
# Processing Record 3 of Set 6 | gizo
# Processing Record 4 of Set 6 | alofi
# Processing Record 5 of Set 6 | marawi
# Processing Record 6 of Set 6 | stephenville
# Processing Record 7 of Set 6 | gamba
# Processing Record 8 of Set 6 | minab
# Processing Record 9 of Set 6 | ahipara
# Processing Record 10 of Set 6 | south sioux city
# Processing Record 11 of Set 6 | san esteban
# Processing Record 12 of Set 6 | blonduos
# City not found. Skipping...
# Processing Record 13 of Set 6 | abay
# Processing Record 14 of Set 6 | cabo san lucas
# Processing Record 15 of Set 6 | burnie
# Processing Record 16 of Set 6 | college
# Processing Record 17 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 18 of Set 6 | fort nelson
# Processing Record 19 of Set 6 | jirikov
# Processing Record 20 of Set 6 | pisco
# Processing Record 21 of Set 6 | olafsvik
# Processing Record 22 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 6 | ouesso
# Processing Record 24 of Set 6 | sisimiut
# Processing Record 25 of Set 6 | qaanaaq
# Processing Record 26 of Set 6 | yashkul
# Processing Record 27 of Set 6 | smithers
# Processing Record 28 of Set 6 | meghraj
# Processing Record 29 of Set 6 | griffith
# Processing Record 30 of Set 6 | antalaha
# Processing Record 31 of Set 6 | luebo
# Processing Record 32 of Set 6 | hambantota
# Processing Record 33 of Set 6 | erattupetta
# Processing Record 34 of Set 6 | kaitangata
# Processing Record 35 of Set 6 | hohhot
# Processing Record 36 of Set 6 | marrakesh
# Processing Record 37 of Set 6 | solnechnyy
# Processing Record 38 of Set 6 | sinop
# Processing Record 39 of Set 6 | kashan
# Processing Record 40 of Set 6 | yeppoon
# Processing Record 41 of Set 6 | port lincoln
# Processing Record 42 of Set 6 | bethel
# Processing Record 43 of Set 6 | anloga
# Processing Record 44 of Set 6 | sampit
# Processing Record 45 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 6 | yulara
# Processing Record 47 of Set 6 | kamaishi
# Processing Record 48 of Set 6 | half moon bay
# Processing Record 49 of Set 6 | beckley
# Processing Record 50 of Set 6 | garissa
# Processing Record 1 of Set 7 | konan
# Processing Record 2 of Set 7 | sao joao da barra
# Processing Record 3 of Set 7 | little chute
# Processing Record 4 of Set 7 | coquimbo
# Processing Record 5 of Set 7 | tahta
# Processing Record 6 of Set 7 | north platte
# Processing Record 7 of Set 7 | letterkenny
# Processing Record 8 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 10 of Set 7 | show low
# Processing Record 11 of Set 7 | maturin
# Processing Record 12 of Set 7 | zhezkazgan
# Processing Record 13 of Set 7 | san quintin
# Processing Record 14 of Set 7 | ye
# City not found. Skipping...
# Processing Record 15 of Set 7 | lata
# Processing Record 16 of Set 7 | primorsk
# Processing Record 17 of Set 7 | rio grande
# Processing Record 18 of Set 7 | longyearbyen
# Processing Record 19 of Set 7 | hushitai
# Processing Record 20 of Set 7 | brae
# Processing Record 21 of Set 7 | mount isa
# Processing Record 22 of Set 7 | hervey bay
# Processing Record 23 of Set 7 | touros
# Processing Record 24 of Set 7 | mayo
# Processing Record 25 of Set 7 | along
# Processing Record 26 of Set 7 | kamenka
# Processing Record 27 of Set 7 | sao sebastiao
# Processing Record 28 of Set 7 | chongwe
# Processing Record 29 of Set 7 | byron bay
# Processing Record 30 of Set 7 | murmashi
# Processing Record 31 of Set 7 | zhigansk
# Processing Record 32 of Set 7 | kostomuksha
# Processing Record 33 of Set 7 | ondangwa
# Processing Record 34 of Set 7 | muhos
# Processing Record 35 of Set 7 | snezhnogorsk
# Processing Record 36 of Set 7 | todos santos
# Processing Record 37 of Set 7 | kailua
# Processing Record 38 of Set 7 | vardo
# Processing Record 39 of Set 7 | imeni stepana razina
# Processing Record 40 of Set 7 | ca mau
# Processing Record 41 of Set 7 | mbala
# Processing Record 42 of Set 7 | billings
# Processing Record 43 of Set 7 | san joaquin
# Processing Record 44 of Set 7 | caravelas
# Processing Record 45 of Set 7 | paita
# Processing Record 46 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 47 of Set 7 | port lavaca
# Processing Record 48 of Set 7 | singleton
# Processing Record 49 of Set 7 | erenhot
# Processing Record 50 of Set 7 | balta
# Processing Record 1 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 2 of Set 8 | lamu
# Processing Record 3 of Set 8 | alta floresta
# Processing Record 4 of Set 8 | luan
# Processing Record 5 of Set 8 | guaymas
# Processing Record 6 of Set 8 | grindavik
# Processing Record 7 of Set 8 | comodoro rivadavia
# Processing Record 8 of Set 8 | ostrovnoy
# Processing Record 9 of Set 8 | newport
# Processing Record 10 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 8 | oinofita
# City not found. Skipping...
# Processing Record 12 of Set 8 | miramar
# Processing Record 13 of Set 8 | boksitogorsk
# Processing Record 14 of Set 8 | hualmay
# Processing Record 15 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 8 | kassala
# Processing Record 17 of Set 8 | pontianak
# Processing Record 18 of Set 8 | frederick
# Processing Record 19 of Set 8 | micheweni
# Processing Record 20 of Set 8 | kisarawe
# Processing Record 21 of Set 8 | pucallpa
# Processing Record 22 of Set 8 | mangrol
# Processing Record 23 of Set 8 | saint john
# Processing Record 24 of Set 8 | wairoa
# Processing Record 25 of Set 8 | gornopravdinsk
# Processing Record 26 of Set 8 | shenjiamen
# Processing Record 27 of Set 8 | barcelona
# Processing Record 28 of Set 8 | labuan
# Processing Record 29 of Set 8 | raisinghnagar
# Processing Record 30 of Set 8 | alugan
# Processing Record 31 of Set 8 | teluknaga
# Processing Record 32 of Set 8 | ulaangom
# Processing Record 33 of Set 8 | biograd na moru
# Processing Record 34 of Set 8 | realeza
# Processing Record 35 of Set 8 | samarai
# Processing Record 36 of Set 8 | lakatoro
# Processing Record 37 of Set 8 | colares
# Processing Record 38 of Set 8 | hasaki
# Processing Record 39 of Set 8 | qostanay
# Processing Record 40 of Set 8 | rorvik
# Processing Record 41 of Set 8 | kamina
# Processing Record 42 of Set 8 | saint-leu
# Processing Record 43 of Set 8 | tacna
# Processing Record 44 of Set 8 | novo aripuana
# Processing Record 45 of Set 8 | ovalle
# Processing Record 46 of Set 8 | castleisland
# Processing Record 47 of Set 8 | christiansburg
# Processing Record 48 of Set 8 | tutoia
# Processing Record 49 of Set 8 | vanimo
# Processing Record 50 of Set 8 | troitsko-pechorsk
# Processing Record 1 of Set 9 | nantucket
# Processing Record 2 of Set 9 | os
# City not found. Skipping...
# Processing Record 3 of Set 9 | celestun
# Processing Record 4 of Set 9 | flinders
# Processing Record 5 of Set 9 | bima
# Processing Record 6 of Set 9 | horsham
# Processing Record 7 of Set 9 | loreto
# Processing Record 8 of Set 9 | tsabong
# Processing Record 9 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 9 | bandarbeyla
# Processing Record 11 of Set 9 | gidrotorf
# Processing Record 12 of Set 9 | taoudenni
# Processing Record 13 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 14 of Set 9 | port augusta
# Processing Record 15 of Set 9 | krasnogorsk
# Processing Record 16 of Set 9 | saint anthony
# Processing Record 17 of Set 9 | abu kamal
# Processing Record 18 of Set 9 | sorland
# Processing Record 19 of Set 9 | monrovia
# Processing Record 20 of Set 9 | mandera
# Processing Record 21 of Set 9 | gijon
# Processing Record 22 of Set 9 | chuguyevka
# Processing Record 23 of Set 9 | paracatu
# Processing Record 24 of Set 9 | kahului
# Processing Record 25 of Set 9 | ranong
# Processing Record 26 of Set 9 | senneterre
# Processing Record 27 of Set 9 | bar harbor
# Processing Record 28 of Set 9 | zilair
# Processing Record 29 of Set 9 | neepawa
# Processing Record 30 of Set 9 | flin flon
# Processing Record 31 of Set 9 | christchurch
# Processing Record 32 of Set 9 | chicama
# Processing Record 33 of Set 9 | sitka
# Processing Record 34 of Set 9 | jiblah
# Processing Record 35 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 9 | bongaree
# Processing Record 37 of Set 9 | mongoumba
# Processing Record 38 of Set 9 | vila franca do campo
# Processing Record 39 of Set 9 | shellbrook
# Processing Record 40 of Set 9 | melfort
# Processing Record 41 of Set 9 | verkhoyansk
# Processing Record 42 of Set 9 | williston
# Processing Record 43 of Set 9 | bonavista
# Processing Record 44 of Set 9 | inirida
# Processing Record 45 of Set 9 | porto-vecchio
# Processing Record 46 of Set 9 | merauke
# Processing Record 47 of Set 9 | point fortin
# Processing Record 48 of Set 9 | karlshamn
# Processing Record 49 of Set 9 | chifeng
# Processing Record 50 of Set 9 | miles city
# Processing Record 1 of Set 10 | cozumel
# Processing Record 2 of Set 10 | hope
# Processing Record 3 of Set 10 | mizan teferi
# Processing Record 4 of Set 10 | soroca
# Processing Record 5 of Set 10 | itarema
# Processing Record 6 of Set 10 | port hardy
# Processing Record 7 of Set 10 | george
# Processing Record 8 of Set 10 | makat
# Processing Record 9 of Set 10 | salalah
# Processing Record 10 of Set 10 | matara
# Processing Record 11 of Set 10 | itacoatiara
# Processing Record 12 of Set 10 | churapcha
# Processing Record 13 of Set 10 | menongue
# Processing Record 14 of Set 10 | stornoway
# Processing Record 15 of Set 10 | maceio
# Processing Record 16 of Set 10 | pochutla
# Processing Record 17 of Set 10 | concordia
# Processing Record 18 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 19 of Set 10 | kambove
# Processing Record 20 of Set 10 | padang
# Processing Record 21 of Set 10 | ware
# Processing Record 22 of Set 10 | lokosovo
# Processing Record 23 of Set 10 | ormara
# Processing Record 24 of Set 10 | mapua
# Processing Record 25 of Set 10 | nuuk
# Processing Record 26 of Set 10 | sao felix do xingu
# Processing Record 27 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 28 of Set 10 | guinguineo
# Processing Record 29 of Set 10 | ixtapa
# Processing Record 30 of Set 10 | sibolga
# Processing Record 31 of Set 10 | jamame
# Processing Record 32 of Set 10 | khorixas
# Processing Record 33 of Set 10 | cayenne
# Processing Record 34 of Set 10 | kununurra
# Processing Record 35 of Set 10 | saint-joseph
# Processing Record 36 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 37 of Set 10 | lesozavodsk
# Processing Record 38 of Set 10 | provideniya
# Processing Record 39 of Set 10 | mayumba
# Processing Record 40 of Set 10 | hobyo
# Processing Record 41 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 42 of Set 10 | belokurikha
# Processing Record 43 of Set 10 | koumac
# Processing Record 44 of Set 10 | trelew
# Processing Record 45 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 46 of Set 10 | srednekolymsk
# Processing Record 47 of Set 10 | yamada
# Processing Record 48 of Set 10 | nambucca heads
# Processing Record 49 of Set 10 | pedasi
# Processing Record 50 of Set 10 | athabasca
# Processing Record 1 of Set 11 | hofn
# Processing Record 2 of Set 11 | lincoln
# Processing Record 3 of Set 11 | naryan-mar
# Processing Record 4 of Set 11 | pangody
# Processing Record 5 of Set 11 | camacupa
# Processing Record 6 of Set 11 | berdigestyakh
# Processing Record 7 of Set 11 | timra
# Processing Record 8 of Set 11 | oussouye
# Processing Record 9 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 10 of Set 11 | san francisco
# Processing Record 11 of Set 11 | arman
# Processing Record 12 of Set 11 | ust-karsk
# Processing Record 13 of Set 11 | wanning
# Processing Record 14 of Set 11 | aksha
# Processing Record 15 of Set 11 | inhambane
# Processing Record 16 of Set 11 | matamoros
# Processing Record 17 of Set 11 | ballina
# Processing Record 18 of Set 11 | meulaboh
# Processing Record 19 of Set 11 | isangel
# Processing Record 20 of Set 11 | sechura
# Processing Record 21 of Set 11 | port keats
# Processing Record 22 of Set 11 | varnavino
# Processing Record 23 of Set 11 | piacabucu
# Processing Record 24 of Set 11 | notse
# Processing Record 25 of Set 11 | borujerd
# Processing Record 26 of Set 11 | nykobing
# City not found. Skipping...
# Processing Record 27 of Set 11 | kirakira
# Processing Record 28 of Set 11 | deputatskiy
# Processing Record 29 of Set 11 | diamantina
# Processing Record 30 of Set 11 | jacareacanga
# Processing Record 31 of Set 11 | riyadh
# Processing Record 32 of Set 11 | bara
# Processing Record 33 of Set 11 | anjar
# Processing Record 34 of Set 11 | orgita
# Processing Record 35 of Set 11 | hegang
# Processing Record 36 of Set 11 | beloha
# Processing Record 37 of Set 11 | damaturu
# Processing Record 38 of Set 11 | elko
# Processing Record 39 of Set 11 | danjiangkou
# Processing Record 40 of Set 11 | kalamare
# Processing Record 41 of Set 11 | oriximina
# Processing Record 42 of Set 11 | cheyenne
# Processing Record 43 of Set 11 | ciudad bolivar
# Processing Record 44 of Set 11 | nizwa
# Processing Record 45 of Set 11 | sandwick
# Processing Record 46 of Set 11 | guerrero negro
# Processing Record 47 of Set 11 | miraflores
# Processing Record 48 of Set 11 | nishihara
# Processing Record 49 of Set 11 | severo-yeniseyskiy
# Processing Record 50 of Set 11 | pemberton
# Processing Record 1 of Set 12 | laguna
# Processing Record 2 of Set 12 | panalingaan
# Processing Record 3 of Set 12 | savannah bight
# Processing Record 4 of Set 12 | gura foii
# Processing Record 5 of Set 12 | jatai
# Processing Record 6 of Set 12 | dillon
# Processing Record 7 of Set 12 | san carlos de bariloche
# Processing Record 8 of Set 12 | tessalit
# Processing Record 9 of Set 12 | mpika
# Processing Record 10 of Set 12 | rogers
# Processing Record 11 of Set 12 | nagua
# Processing Record 12 of Set 12 | jiangkou
# Processing Record 13 of Set 12 | kloulklubed
# Processing Record 14 of Set 12 | port hedland
# Processing Record 15 of Set 12 | mandalgovi
# Processing Record 16 of Set 12 | port blair
# Processing Record 17 of Set 12 | rawlins
# Processing Record 18 of Set 12 | nguruka
# Processing Record 19 of Set 12 | fortuna
# Processing Record 20 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 21 of Set 12 | airai
# Processing Record 22 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 12 | amurzet
# Processing Record 24 of Set 12 | iquitos
# Processing Record 25 of Set 12 | saint-pierre
# Processing Record 26 of Set 12 | zhongshan
# Processing Record 27 of Set 12 | sovetskiy
# Processing Record 28 of Set 12 | alyangula
# Processing Record 29 of Set 12 | port-cartier
# Processing Record 30 of Set 12 | tamboril
# Processing Record 31 of Set 12 | cristobal obregon
# Processing Record 32 of Set 12 | najran
# Processing Record 33 of Set 12 | hokitika
# Processing Record 34 of Set 12 | nucsoara
# Processing Record 35 of Set 12 | swan river
# Processing Record 36 of Set 12 | tezu
# Processing Record 37 of Set 12 | kyrylivka
# Processing Record 38 of Set 12 | sur
# Processing Record 39 of Set 12 | oros
# Processing Record 40 of Set 12 | awbari
# Processing Record 41 of Set 12 | marienburg
# Processing Record 42 of Set 12 | san rafael
# Processing Record 43 of Set 12 | dalmatovo
# Processing Record 44 of Set 12 | mana
# Processing Record 45 of Set 12 | qasigiannguit
# Processing Record 46 of Set 12 | yar-sale
# Processing Record 47 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 48 of Set 12 | nirmal
# Processing Record 49 of Set 12 | virginia beach
# Processing Record 50 of Set 12 | bloomfield
# Processing Record 1 of Set 13 | kyra
# Processing Record 2 of Set 13 | mackenzie
# Processing Record 3 of Set 13 | millinocket
# Processing Record 4 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 5 of Set 13 | tomatlan
# Processing Record 6 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 13 | antofagasta
# Processing Record 8 of Set 13 | ghatsila
# Processing Record 9 of Set 13 | plattsburgh
# Processing Record 10 of Set 13 | hamilton
# Processing Record 11 of Set 13 | ponta delgada
# Processing Record 12 of Set 13 | ancud
# Processing Record 13 of Set 13 | jahrom
# City not found. Skipping...
# Processing Record 14 of Set 13 | buala
# Processing Record 15 of Set 13 | dongsheng
# Processing Record 16 of Set 13 | prainha
# Processing Record 17 of Set 13 | sept-iles
# Processing Record 18 of Set 13 | lavrentiya
# Processing Record 19 of Set 13 | novyye burasy
# Processing Record 20 of Set 13 | sistranda
# Processing Record 21 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 13 | manggar
# Processing Record 23 of Set 13 | zhangjiakou
# Processing Record 24 of Set 13 | biak
# Processing Record 25 of Set 13 | selikhino
# Processing Record 26 of Set 13 | dvinskoy
# Processing Record 27 of Set 13 | praia da vitoria
# Processing Record 28 of Set 13 | vostok
# Processing Record 29 of Set 13 | nacala
# Processing Record 30 of Set 13 | santo domingo
# Processing Record 31 of Set 13 | charyshskoye
# Processing Record 32 of Set 13 | necochea
# Processing Record 33 of Set 13 | toktogul
# Processing Record 34 of Set 13 | gunnedah
# Processing Record 35 of Set 13 | dongying
# Processing Record 36 of Set 13 | shaoyang
# Processing Record 37 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 38 of Set 13 | khasan
# Processing Record 39 of Set 13 | skjervoy
# Processing Record 40 of Set 13 | eureka
# Processing Record 41 of Set 13 | mme
# City not found. Skipping...
# Processing Record 42 of Set 13 | truth or consequences
# Processing Record 43 of Set 13 | puerto escondido
# Processing Record 44 of Set 13 | mokrous
# Processing Record 45 of Set 13 | tautira
# Processing Record 46 of Set 13 | galveston
# Processing Record 47 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 48 of Set 13 | marevo
# Processing Record 49 of Set 13 | grasse
# Processing Record 50 of Set 13 | guajara-mirim
# City not found. Skipping...
# Processing Record 1 of Set 14 | weiser
# Processing Record 2 of Set 14 | saint-georges
# Processing Record 3 of Set 14 | kalmunai
# Processing Record 4 of Set 14 | rychnov nad kneznou
# Processing Record 5 of Set 14 | totness
# Processing Record 6 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 14 | namatanai
# Processing Record 8 of Set 14 | honiara
# Processing Record 9 of Set 14 | kaiyuan
# Processing Record 10 of Set 14 | arivonimamo
# Processing Record 11 of Set 14 | polunochnoye
# Processing Record 12 of Set 14 | marshall
# Processing Record 13 of Set 14 | ugoofaaru
# Processing Record 14 of Set 14 | dolzhanskaya
# Processing Record 15 of Set 14 | tancanhuitz
# Processing Record 16 of Set 14 | shevchenko
# Processing Record 17 of Set 14 | colesberg
# Processing Record 18 of Set 14 | shirokiy
# Processing Record 19 of Set 14 | kushima
# Processing Record 20 of Set 14 | constantine
# Processing Record 21 of Set 14 | hami
# Processing Record 22 of Set 14 | dutse
# Processing Record 23 of Set 14 | richards bay
# Processing Record 24 of Set 14 | saint-ambroise
# Processing Record 25 of Set 14 | toora-khem
# Processing Record 26 of Set 14 | payo
# Processing Record 27 of Set 14 | capaci
# Processing Record 28 of Set 14 | mildura
# Processing Record 29 of Set 14 | constitucion
# Processing Record 30 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 31 of Set 14 | acolla
# Processing Record 32 of Set 14 | dhidhdhoo
# Processing Record 33 of Set 14 | rahatgarh
# Processing Record 34 of Set 14 | havoysund
# Processing Record 35 of Set 14 | valparaiso
# Processing Record 36 of Set 14 | garowe
# Processing Record 37 of Set 14 | honningsvag
# Processing Record 38 of Set 14 | southampton
# Processing Record 39 of Set 14 | canitas
# City not found. Skipping...
# Processing Record 40 of Set 14 | tawau
# Processing Record 41 of Set 14 | truro
# Processing Record 42 of Set 14 | daloa
# Processing Record 43 of Set 14 | omboue
# Processing Record 44 of Set 14 | yevsino
# Processing Record 45 of Set 14 | beruwala
# Processing Record 46 of Set 14 | imeni poliny osipenko
# Processing Record 47 of Set 14 | marv dasht
# City not found. Skipping...
# Processing Record 48 of Set 14 | lundazi
# Processing Record 49 of Set 14 | montepuez
# Processing Record 50 of Set 14 | ekhabi
# Processing Record 1 of Set 15 | san patricio
# Processing Record 2 of Set 15 | borger
# Processing Record 3 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 15 | lephepe
# City not found. Skipping...
# Processing Record 5 of Set 15 | mazatan
# Processing Record 6 of Set 15 | raufoss
# Processing Record 7 of Set 15 | kholm
# Processing Record 8 of Set 15 | xichang
# Processing Record 9 of Set 15 | susner
# Processing Record 10 of Set 15 | grand gaube
# Processing Record 11 of Set 15 | killybegs
# Processing Record 12 of Set 15 | arlit
# Processing Record 13 of Set 15 | ta khmau
# Processing Record 14 of Set 15 | thaba-tseka
# Processing Record 15 of Set 15 | harnai
# Processing Record 16 of Set 15 | daru
# Processing Record 17 of Set 15 | mareeba
# Processing Record 18 of Set 15 | jibuti
# Processing Record 19 of Set 15 | kutum
# Processing Record 20 of Set 15 | plast
# Processing Record 21 of Set 15 | uravakonda
# Processing Record 22 of Set 15 | bajil
# Processing Record 23 of Set 15 | datong
# Processing Record 24 of Set 15 | maku
# Processing Record 25 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 15 | launceston
# Processing Record 27 of Set 15 | porto novo
# Processing Record 28 of Set 15 | rusape
# Processing Record 29 of Set 15 | karratha
# Processing Record 30 of Set 15 | matagami
# Processing Record 31 of Set 15 | zhanatas
# City not found. Skipping...
# Processing Record 32 of Set 15 | grand-bourg
# Processing Record 33 of Set 15 | cabedelo
# Processing Record 34 of Set 15 | esperance
# Processing Record 35 of Set 15 | moron
# Processing Record 36 of Set 15 | ambulu
# Processing Record 37 of Set 15 | idar
# Processing Record 38 of Set 15 | axim
# Processing Record 39 of Set 15 | benguela
# Processing Record 40 of Set 15 | kobayashi
# Processing Record 41 of Set 15 | bilecik
# Processing Record 42 of Set 15 | oranjemund
# Processing Record 43 of Set 15 | galesburg
# Processing Record 44 of Set 15 | tiznit
# Processing Record 45 of Set 15 | linfen
# Processing Record 46 of Set 15 | kenora
# Processing Record 47 of Set 15 | kalnciems
# Processing Record 48 of Set 15 | terrace
# Processing Record 49 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 15 | altay
# Processing Record 1 of Set 16 | lesnoye
# Processing Record 2 of Set 16 | hunza
# City not found. Skipping...
# Processing Record 3 of Set 16 | palmas
# Processing Record 4 of Set 16 | mazagao
# Processing Record 5 of Set 16 | sumbe
# Processing Record 6 of Set 16 | tadine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 696

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kiunga  -6.1219  141.2906     71.98        99         100
# 1           Pauini  -7.7136  -66.9764     90.21        51          73
# 2  Plettenberg Bay -34.0527   23.3716     70.90        70           0
# 3          Iqaluit  63.7506  -68.5145      6.53        84          75
# 4             Naze  28.3667  129.4833     50.92        73          98
# 5  Bambous Virieux -20.3428   57.7575     76.21        78          20
# 6        Busselton -33.6500  115.3333     63.14        71           9
# 7        Kavaratti  10.5669   72.6420     81.52        65          59
# 8             Dali  25.7000  100.1833     42.94        76           2
# 9     Saint George  37.1041 -113.5841     36.19        64           0
#
#    Wind Speed Country Weather Description
# 0        2.39      PG     overcast clouds
# 1        1.54      BR       broken clouds
# 2       12.10      ZA           clear sky
# 3        3.44      CA       broken clouds
# 4       26.49      JP          light rain
# 5        3.44      MU          few clouds
# 6        9.46      AU           clear sky
# 7        6.82      IN       broken clouds
# 8        3.89      CN           clear sky
# 9        0.00      US           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kiunga      PG  -6.1219  141.2906     71.98        99         100
# 1           Pauini      BR  -7.7136  -66.9764     90.21        51          73
# 2  Plettenberg Bay      ZA -34.0527   23.3716     70.90        70           0
# 3          Iqaluit      CA  63.7506  -68.5145      6.53        84          75
# 4             Naze      JP  28.3667  129.4833     50.92        73          98
# 5  Bambous Virieux      MU -20.3428   57.7575     76.21        78          20
# 6        Busselton      AU -33.6500  115.3333     63.14        71           9
# 7        Kavaratti      IN  10.5669   72.6420     81.52        65          59
# 8             Dali      CN  25.7000  100.1833     42.94        76           2
# 9     Saint George      US  37.1041 -113.5841     36.19        64           0
#
#    Wind Speed Weather Description
# 0        2.39     overcast clouds
# 1        1.54       broken clouds
# 2       12.10           clear sky
# 3        3.44       broken clouds
# 4       26.49          light rain
# 5        3.44          few clouds
# 6        9.46           clear sky
# 7        6.82       broken clouds
# 8        3.89           clear sky
# 9        0.00           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
